# %%
import pandas as pd
from datetime import datetime

# %%
# Load the dataset
df = pd.read_csv("daikin_purchase_orders.csv")

# %%
#Exploratory Data Analysis
#Loading first rows of the dataset to ensure it loaded correctly
df.head()
# Out:
#   Purchase_Order_Number Component_Code Component_Description  Quantity  \
# 0                PO1001       COMP-001       Compressor Unit       500
# 1                PO1002       COMP-002        Condenser Coil       800
# 2                PO1003       COMP-003       Evaporator Coil       700
# 3                PO1004       COMP-004          Blower Motor      1000
# 4                PO1005       COMP-005       Expansion Valve      1200
#
#    Unit_Price  Total_Price  Order_Date Delivery_Date     Status
# 0         200       100000  2021-01-05    2021-01-15  Delivered
# 1         100        80000  2021-01-10    2021-01-20  Delivered
# 2          80        56000  2021-02-02    2021-02-12  Delivered
# 3          50        50000  2021-02-15    2021-02-25  Delivered
# 4          20        24000  2021-03-10    2021-03-20  Delivered

# %%
# Check the data types of each column
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# Purchase_Order_Number    object
# Component_Code           object
# Component_Description    object
# Quantity                  int64
# Unit_Price                int64
# Total_Price               int64
# Order_Date               object
# Delivery_Date            object
# Status                   object
# dtype: object

# %%
# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Purchase_Order_Number    0
# Component_Code           0
# Component_Description    0
# Quantity                 0
# Unit_Price               0
# Total_Price              0
# Order_Date               0
# Delivery_Date            0
# Status                   0
# dtype: int64

# %%
# Summary statistics
print("\nSummary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#            Quantity  Unit_Price    Total_Price
# count     50.000000   50.000000      50.000000
# mean    2816.000000   64.700000   62160.000000
# std     4352.637483   64.656155   43360.195233
# min      300.000000    2.000000   10000.000000
# 25%      825.000000   10.000000   26250.000000
# 50%     1300.000000   40.000000   47500.000000
# 75%     2375.000000  100.000000   94500.000000
# max    20000.000000  200.000000  180000.000000

# %%
# Check for duplicates
print("\nDuplicates:")
print(df.duplicated().sum())
# Out:
# Duplicates:
# 0

# %%
#Data Transformation
# Convert dates to datetime objects
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'])

# %%
# KPI 1: 
# Cost Savings: Reduction in purchase costs through better negotiation and supplier selection. 
# You can analyze the total spend by supplier or identify the top suppliers based on total spend
supplier_spend = df.groupby('Component_Description')['Total_Price'].sum().sort_values(ascending=False)
print("\nTop Components by Total Spend:")
print(supplier_spend)
# Out:
# Top Components by Total Spend:
# Component_Description
# Compressor Unit    700000
# Condenser Coil     570000
# Evaporator Coil    408000
# Blower Motor       375000
# Heat Exchanger     375000
# Expansion Valve    180000
# Control Board      150000
# Refrigerant Gas    150000
# Thermostat         125000
# Fan Blade           75000
# Name: Total_Price, dtype: int64

# %%
# KPI 2: 
# Supplier Lead Time: Time taken from order placement to delivery.
df['Lead_Time'] = (df['Delivery_Date'] - df['Order_Date']).dt.days
avg_lead_time = df['Lead_Time'].mean()
print("\nAverage Supplier Lead Time (days):", avg_lead_time)
# Out:
# Average Supplier Lead Time (days): 10.0

# %%
# KPI 3: Order Accuracy
# Calculate the percentage of orders delivered correctly and on time
on_time_orders = df[df['Status'] == 'Delivered']
accuracy = (on_time_orders.shape[0] / df.shape[0]) * 100
print("\nOrder Accuracy (%):", accuracy)
# Out:
# Order Accuracy (%): 100.0

# %%
df.head(50)
# Out:
#    Purchase_Order_Number Component_Code Component_Description  Quantity  \
# 0                 PO1001       COMP-001       Compressor Unit       500
# 1                 PO1002       COMP-002        Condenser Coil       800
# 2                 PO1003       COMP-003       Evaporator Coil       700
# 3                 PO1004       COMP-004          Blower Motor      1000
# 4                 PO1005       COMP-005       Expansion Valve      1200
# 5                 PO1006       COMP-006        Heat Exchanger       300
# 6                 PO1007       COMP-007            Thermostat      1500
# 7                 PO1008       COMP-008         Control Board       600
# 8                 PO1009       COMP-009             Fan Blade      2000
# 9                 PO1010       COMP-010       Refrigerant Gas     10000
# 10                PO1011       COMP-011       Compressor Unit       600
# 11                PO1012       COMP-012        Condenser Coil      1000
# 12                PO1013       COMP-013       Evaporator Coil       900
# 13                PO1014       COMP-014          Blower Motor      1200
# 14                PO1015       COMP-015       Expansion Valve      1500
# 15                PO1016       COMP-016        Heat Exchanger       400
# 16                PO1017       COMP-017            Thermostat      2000
# 17                PO1018       COMP-018         Control Board       800
# 18                PO1019       COMP-019             Fan Blade      2500
# 19                PO1020       COMP-020       Refrigerant Gas     12000
# 20                PO1021       COMP-021       Compressor Unit       700
# 21                PO1022       COMP-022        Condenser Coil      1200
# 22                PO1023       COMP-023       Evaporator Coil      1000
# 23                PO1024       COMP-024          Blower Motor      1500
# 24                PO1025       COMP-025       Expansion Valve      1800
# 25                PO1026       COMP-026        Heat Exchanger       500
# 26                PO1027       COMP-027            Thermostat      2500
# 27                PO1028       COMP-028         Control Board      1000
# 28                PO1029       COMP-029             Fan Blade      3000
# 29                PO1030       COMP-030       Refrigerant Gas     15000
# 30                PO1031       COMP-031       Compressor Unit       800
# 31                PO1032       COMP-032        Condenser Coil      1300
# 32                PO1033       COMP-033       Evaporator Coil      1200
# 33                PO1034       COMP-034          Blower Motor      1800
# 34                PO1035       COMP-035       Expansion Valve      2000
# 35                PO1036       COMP-036        Heat Exchanger       600
# 36                PO1037       COMP-037            Thermostat      3000
# 37                PO1038       COMP-038         Control Board      1200
# 38                PO1039       COMP-039             Fan Blade      3500
# 39                PO1040       COMP-040       Refrigerant Gas     18000
# 40                PO1041       COMP-041       Compressor Unit       900
# 37          30        36000 2022-07-10    2022-07-20  Delivered         10
# 38           5        17500 2022-08-05    2022-08-15  Delivered         10
# 39           2        36000 2022-08-10    2022-08-20  Delivered         10
# 40         200       180000 2022-09-05    2022-09-15  Delivered         10
# 41         100       140000 2022-09-10    2022-09-20  Delivered         10
# 42          80       104000 2022-10-02    2022-10-12  Delivered         10
# 43          50       100000 2022-10-15    2022-10-25  Delivered         10
# 44          20        50000 2022-11-10    2022-11-20  Delivered         10
# 45         150       105000 2022-11-15    2022-11-25  Delivered         10
# 46          10        35000 2022-12-02    2022-12-12  Delivered         10
# 47          30        42000 2022-12-10    2022-12-20  Delivered         10
# 48           5        20000 2023-01-05    2023-01-15  Delivered         10
# 49           2        40000 2023-01-10    2023-01-20  Delivered         10
#
#     Supplier_Rating
# 0               4.0
# 1               4.0
# 2               4.0
# 3               4.0
# 4               4.0
# 5               4.0
# 6               4.0
# 7               4.0
# 8               4.0
# 9               4.0
# 10              4.0
# 11              4.0
# 12              4.0
# 13              4.0
# 14              4.0
# 15              4.0
# 16              4.0
# 17              4.0
# 18              4.0
# 19              4.0
# 20              4.0
# 21              4.0
# 22              4.0
# 23              4.0
# 24              4.0
# 25              4.0
# 26              4.0
# 27              4.0
# 28              4.0
# 29              4.0
# 30              4.0
# 31              4.0
# 32              4.0
# 33              4.0
# 34              4.0
# 35              4.0
# 36              4.0
# 37              4.0
# 38              4.0
# 39              4.0
# 40              4.0
# 41              4.0
# 42              4.0
# 43              4.0
# 44              4.0
# 45              4.0
# 46              4.0
# 47              4.0
# 48              4.0
# 49              4.0

# %%
# KPI 4: Supplier Performance
# You can calculate a rating based on delivery, quality, and compliance
# For simplicity, let's assume a rating scale of 1 to 5 based on lead time and accuracy
df['Supplier_Rating'] = 5 - df['Lead_Time'] / avg_lead_time
df.loc[df['Supplier_Rating'] < 1, 'Supplier_Rating'] = 1
df.loc[df['Status'] != 'Delivered', 'Supplier_Rating'] = 1
supplier_performance = df.groupby('Component_Description')['Supplier_Rating'].mean().sort_values(ascending=False)
print("\nComponent Performance Ratings:")
print(supplier_performance)
# Out:
# Component Performance Ratings:
# Component_Description
# Blower Motor       4.0
# Compressor Unit    4.0
# Condenser Coil     4.0
# Control Board      4.0
# Evaporator Coil    4.0
# Expansion Valve    4.0
# Fan Blade          4.0
# Heat Exchanger     4.0
# Refrigerant Gas    4.0
# Thermostat         4.0
# Name: Supplier_Rating, dtype: float64

# %%
# KPI 5: Spend Under Management
# Calculate the percentage of total spend managed by the procurement team
total_spend = df['Total_Price'].sum()
procurement_spend = df[df['Status'] == 'Delivered']['Total_Price'].sum()
spend_under_management = (procurement_spend / total_spend) * 100
print("\nSpend Under Management (%):", spend_under_management)
# Out:
# Spend Under Management (%): 100.0
